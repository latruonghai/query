# %%
from Crawl import Crawl
from CrawlVnE import CrawlVnE

# %%
class CrawlAgoda(Crawl):
    
    def __init__(self, url):
        super.__init(url)
    
    def letCrawl():

# %%
cr = CrawlVnE('https://vnexpress.net/the-gioi',2)
cd = cr.get_page_content('https://giaoducthoidai.vn/gia-dinh/4-dac-diem-cua-dan-ong-luon-khien-phu-nu-phai-dieu-dung--20200701192340526.html')
cd
# Out:
# <!DOCTYPE html>
#
# <html id="mainHtml" lang="vi">
# <head>
# <meta content="width=device-width, user-scalable=no, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0" device="Desktop" name="viewport"/>
# <meta content="text/html;charset=utf-8" http-equiv="Content-Type">
# <link href="https://giaoducthoidai.vn/images/favicon.ico" rel="icon" type="image/png"/>
# <meta content="oj4ZE7Ft2rWUHKA7OP7vLkdggZYsxjqPVYd0tfD3enE" name="google-site-verification"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="address=no" name="format-detection"/>
# <meta content="index, follow" name="robots"/>
# <meta content="index, follow, archive, snippet" name="Googlebot-News"/>
# <meta content="index, follow, archive, snippet" name="googlebot"/>
# <meta content="vi" name="Language">
# <meta content="Global" name="distribution">
# <meta content="1 days" name="revisit-after">
# <meta content="© Báo Giáo dục và Thời đại" name="copyright"/>
# ...

# %%
help(CrawlVnE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0a992ecb2935> in <module>
# ----> 1 help(CrawlVnE)
#
# NameError: name 'CrawlVnE' is not defined

# %%
time.times()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-37a05bb7557e> in <module>
# ----> 1 time.times()
#
# AttributeError: module 'time' has no attribute 'times'

# %%
import pandas as pd
import json

# %%
# a = pd.DataFrame()
b = {'A': 'Wikipedia', 'Content': ['Tôi là ai', 'Đây là đâu']}
with open('Hai.json','w+') as file:
    json.dump(b,file,ensure_ascii = False)
a.to_json('hai.json', force_ascii = False)

# %%
a = {'Hai':1}
a['Hai'] =2

# %%
help(json)
# Out:
# Help on package json:
#
# NAME
#     json
#
# MODULE REFERENCE
#     https://docs.python.org/3.8/library/json
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     JSON (JavaScript Object Notation) <http://json.org> is a subset of
#     JavaScript syntax (ECMA-262 3rd edition) used as a lightweight data
#     interchange format.
#
#     :mod:`json` exposes an API familiar to users of the standard library
#     :mod:`marshal` and :mod:`pickle` modules.  It is derived from a
#     version of the externally maintained simplejson library.
#
#     Encoding basic Python object hierarchies::
#
#         >>> import json
#         >>> json.dumps(['foo', {'bar': ('baz', None, 1.0, 2)}])
# ...
